# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
#Seaborn has some datasets inbuilt
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
titanic=sns.load_dataset("titanic")

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic['age'].plot() # By default its a line plot
# Out:
# <AxesSubplot:>

# %%
titanic['age'].plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['age'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
titanic['class'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='class'>

# %%
titanic['sex'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
titanic['who'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='who'>

# %%
titanic['who'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='who',data=titanic)
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %%
sns.displot(titanic["age"],kde=False)

# %%
sns.displot(x='age', kind='kde',hue='sex',data=titanic)

# %%
type(k)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
sns.displot(x='age', kind='kde',hue='sex',col='class',data=titanic)

# %%
g=sns.displot(x='age', kind='ecdf',hue='sex',col='class',data=titanic)

# %%
type(g)

# %%
sns.displot(x='age', kind='kde',hue='sex',col='class',row='embark_town',data=titanic)
# Out:
# /Users/gopi/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/gopi/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/gopi/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/gopi/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
sns.lmplot(x="total_bill", y="tip",data=tips,fit_reg=False)

# %%
sns.lmplot(x="total_bill", y="tip", hue='sex',data=tips,fit_reg=False)

# %%
sns.lmplot(x="total_bill", y="tip",data=tips,fit_reg=True)

# %%
sns.lmplot(x="total_bill", y="tip",hue='sex',data=tips,fit_reg=True)

# %%
sns.lmplot(x="total_bill", y="tip",hue='sex',row='smoker',data=tips,fit_reg=False)

# %%
sns.lmplot(x="total_bill", y="tip",hue='sex',col='smoker',row='day',data=tips,fit_reg=False)

# %%
sns.set_theme(context='paper',color_codes=True,font_scale=2)

# %%
sns.set_context()

# %%
sns.lmplot(x="total_bill", y="tip",hue='sex',data=tips,fit_reg=True)

# %%
# save figure
f=sns.lmplot(x="total_bill", y="tip",hue='sex',data=tips,fit_reg=True)
f.savefig("test_regres",format="pdf")

# %%
# !pwd
# Out:
# /Users/gopi/Desktop/DataScince_Course/datawrangling

# %%
type(f)

# %%
import matplotlib.pyplot as plt

# %%
fg,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
sns.distplot(titanic.age,kde=False,ax=ax1)
sns.distplot(titanic.age,kde=True,ax=ax2)
fg.tight_layout()

# %%
sns.distplot(titanic.age,kde=False)
# Out:
# /Users/gopi/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age'>
