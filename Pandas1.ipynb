# %% [markdown]
# # What is pandas?
# + Python library for data analysis
# + High-performance containers for data analysis
# + Data structures with a lot of functionality
# + Meaningful labels
# + Time series functionality Handling missing data
# + Relational operations

# %% [markdown]
# ## Three main data structures of Pandas
#
# + Series
#
# + Data Frames
#
# + Data Panels

# %%
import pandas as pd   # pd aliasing is convention

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
#  '_lib',
#  '_libs',
#  '_np_version_under1p16',
#  '_np_version_under1p17',
#  '_np_version_under1p18',
#  '_testing',
#  '_tslib',
#  '_typing',
#  '_version',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# ## Loading the csv file data into a pandas DataFrame.

# %%
df = pd.read_csv('./Data/AAPL.csv')  # try to explore several options of read_csv

# %%
#pd.read_csv()  #explore how many types of files formats pandas can read

# %%
# printing first five rows of the data frame
#df.head()  # 5 is the default value. we can ask for any number as shown below
df.head(3)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900

# %%
# display specific number of rows from bottom of the file 5 is the default 
df.tail(8)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 13  2018-06-08  191.169998  192.000000  189.770004  191.699997  191.699997
# 14  2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 15  2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 16  2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
# 19  2018-06-18  187.880005  189.220001  187.199997  188.740005  188.740005
# 20  2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#       Volume
# 13  26656800
# 14  18308500
# 15  16911100
# 16  21638400
# 17  21610100
# 18  61719200
# 19  18484900
# 20  32502500

# %% [markdown]
# #### Above we get to see all the data of the csv file are neatly arranged in a tabular format called data frame.
# #### Each row of data is associated with an index. Here the indices are automatically generated integers starting from zero.

# %%
# How the python builtin type function interprets the object df?
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns    # what are all te
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# reading csv file with first column as index 

df = pd.read_csv('./Data/AAPL.csv')

# Here we have dates as the index unlike numbers starting from zero as in previous case
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900
# 3  20401000
# 4  17461000

# %% [markdown]
# ### Some pandas data frame attributes and methods

# %%
df.index
# Out:
# Index(['2018-05-21', '2018-05-22', '2018-05-23', '2018-05-24', '2018-05-25',
#        '2018-05-29', '2018-05-30', '2018-05-31', '2018-06-01', '2018-06-04',
#        '2018-06-05', '2018-06-06', '2018-06-07', '2018-06-08', '2018-06-11',
#        '2018-06-12', '2018-06-13', '2018-06-14', '2018-06-15', '2018-06-18',
#        '2018-06-19'],
#       dtype='object', name='Date')

# %%
# how many rows and columns?
df.shape
# Out:
# (21, 7)

# %%
# summary of information about the data frame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       21 non-null     object
#  1   Open       21 non-null     float64
#  2   High       21 non-null     float64
#  3   Low        21 non-null     float64
#  4   Close      21 non-null     float64
#  5   Adj Close  21 non-null     float64
#  6   Volume     21 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# statistical information related to the data frame
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count   21.000000   21.000000   21.000000   21.000000   21.000000
# mean   189.698573  190.607620  188.548571  189.759524  189.759524
# std      2.543028    2.319233    2.506535    2.402797    2.402797
# min    185.139999  186.330002  183.449997  185.690002  185.690002
# 25%    187.880005  188.839996  186.779999  187.899994  187.899994
# 50%    188.770004  190.160004  187.750000  188.839996  188.839996
# 75%    191.550003  192.610001  190.440002  191.699997  191.699997
# max    194.139999  194.199997  192.360001  193.979996  193.979996
#
#              Volume
# count  2.100000e+01
# mean   2.336069e+07
# std    9.676355e+06
# min    1.524070e+07
# 25%    1.848490e+07
# 50%    2.134720e+07
# 75%    2.325040e+07
# max    6.171920e+07

# %% [markdown]
# ### Accessing Columns

# %%
# Each column can be accessed with the column name as shown below 
# We use squre brackets just like a pyton List

df_open = df['Open']
print(df_open)
# Out:
# 0     188.000000
# 1     188.380005
# 2     186.350006
# 3     188.770004
# 4     188.229996
# 5     187.600006
# 6     187.720001
# 7     187.220001
# 8     187.990005
# 9     191.639999
# 10    193.070007
# 11    193.630005
# 12    194.139999
# 13    191.169998
# 14    191.350006
# 15    191.389999
# 16    192.419998
# 17    191.550003
# 18    190.029999
# 19    187.880005
# 20    185.139999
# Name: Open, dtype: float64

# %%
# what is that returned? 
type(df_open)  # it is a Pandas Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Series is just like a list associated with index

# %%
# we can even access multiple columns of a data frame
#df['Open','Close']  
df[['Open','Close']]  # we need to pass the list of columns that we want access. Not just the individual column names
# Out:
#           Open       Close
# 0   188.000000  187.630005
# 1   188.380005  187.160004
# 2   186.350006  188.360001
# 3   188.770004  188.149994
# 4   188.229996  188.580002
# 5   187.600006  187.899994
# 6   187.720001  187.500000
# 7   187.220001  186.869995
# 8   187.990005  190.240005
# 9   191.639999  191.830002
# 10  193.070007  193.309998
# 11  193.630005  193.979996
# 12  194.139999  193.460007
# 13  191.169998  191.699997
# 14  191.350006  191.229996
# 15  191.389999  192.279999
# 16  192.419998  190.699997
# 17  191.550003  190.800003
# 18  190.029999  188.839996
# 19  187.880005  188.740005
# 20  185.139999  185.690002

# %%
type(df[['Open','Close']] )   # This retuns us a Data Frame as we tried to access more than one column
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Open']].head()
# Out:
#          Open
# 0  188.000000
# 1  188.380005
# 2  186.350006
# 3  188.770004
# 4  188.229996

# %%
df[['Close','Open']]   # Observe the change of order in column names
# Out:
#          Close        Open
# 0   187.630005  188.000000
# 1   187.160004  188.380005
# 2   188.360001  186.350006
# 3   188.149994  188.770004
# 4   188.580002  188.229996
# 5   187.899994  187.600006
# 6   187.500000  187.720001
# 7   186.869995  187.220001
# 8   190.240005  187.990005
# 9   191.830002  191.639999
# 10  193.309998  193.070007
# 11  193.979996  193.630005
# 12  193.460007  194.139999
# 13  191.699997  191.169998
# 14  191.229996  191.350006
# 15  192.279999  191.389999
# 16  190.699997  192.419998
# 17  190.800003  191.550003
# 18  188.839996  190.029999
# 19  188.740005  187.880005
# 20  185.690002  185.139999

# %% [markdown]
# ## Accessing Rows

# %%
dft=df.head()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.reset_index()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1   2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2   2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3   2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4   2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
# 5   2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 6   2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 7   2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
# 8   2018-06-01  187.990005  190.259995  187.750000  190.240005  190.240005
# 9   2018-06-04  191.639999  193.419998  191.350006  191.830002  191.830002
# 10  2018-06-05  193.070007  193.940002  192.360001  193.309998  193.309998
# 11  2018-06-06  193.630005  194.080002  191.919998  193.979996  193.979996
# 12  2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 13  2018-06-08  191.169998  192.000000  189.770004  191.699997  191.699997
# 14  2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 15  2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 16  2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
# 19  2018-06-18  187.880005  189.220001  187.199997  188.740005  188.740005
# 20  2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#       Volume
# 0   18400800
# 1   15240700
# 2   19467900
# 3   20401000
# 4   17461000
# 5   22369000
# 6   18690500
# 7   27482800
# 8   23250400
# 9   26132000
# 10  21566000
# 11  20933600
# 12  21347200
# 13  26656800
# 14  18308500
# 15  16911100
# 16  21638400
# 17  21610100
# 18  61719200
# 19  18484900
# 20  32502500

# %%
df[0] # Try to understand the error ... Its searching in columns !!! 
                 # its reserved for columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-d7f2aa46669e> in <module>
# ----> 1 df[0] # Try to understand the error ... Its searching in columns !!!
#       2                  # its reserved for columns
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# ## Slicing rows

# %%
df[0:3]    # but we can give range of index values and access the corresponding rows
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900

# %%
df[2:3] # for accessing single row
# Out:
#          Date        Open   High         Low       Close   Adj Close    Volume
# 2  2018-05-23  186.350006  188.5  185.759995  188.360001  188.360001  19467900

# %% [markdown]
# ### Observe the capabaility of date time interpretation by pandas

# %%
df['2018-05-21':'2018-05-28']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %% [markdown]
# ### How to access a single row?

# %%
df['2018-05-21':'2018-05-21']  # But it returns not a series but a data frame
# Out:
#              Open        High         Low       Close   Adj Close    Volume
# Date
# 2018-05-21  188.0  189.270004  186.910004  187.630005  187.630005  18400800

# %%
type(df['2018-05-21':'2018-05-21'])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### What the Open share value on 2018-05-25 ? How do we get it?

# %%
df['Open']['2018-05-25']    # try some more
# Out:
# 188.229996

# %% [markdown]
# ## Accessors
# ###   .loc  &nbsp;&nbsp;&nbsp;&nbsp;  - Uses Labels
# ###  .iloc   &nbsp;&nbsp;&nbsp;&nbsp;    - Uses Locations

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900
# 3  20401000
# 4  17461000

# %%
df.loc[3:5,['Date','Open']]
# Out:
#          Date        Open
# 3  2018-05-24  188.770004
# 4  2018-05-25  188.229996
# 5  2018-05-29  187.600006

# %%
df.loc['2018-05-21','Open']
# Out:
# 188.0

# %%
df.loc['2018-05-21',['Open','Volume']]
# Out:
# Open           188.0
# Volume    18400800.0
# Name: 2018-05-21, dtype: float64

# %%
df.loc[['2018-05-21','2018-05-25'],['Open','Volume']]
# Out:
#                   Open    Volume
# Date
# 2018-05-21  188.000000  18400800
# 2018-05-25  188.229996  17461000

# %%
df.loc['2018-05-30'::2,['Open','Volume']]   # What is that we are trying to do here?
# Out:
#                   Open    Volume
# Date
# 2018-05-30  187.720001  18690500
# 2018-06-01  187.990005  23250400
# 2018-06-05  193.070007  21566000
# 2018-06-07  194.139999  21347200
# 2018-06-11  191.350006  18308500
# 2018-06-13  192.419998  21638400
# 2018-06-15  190.029999  61719200
# 2018-06-19  185.139999  32502500

# %%
df.iloc[0:4,3:5]   # returns element of first row and first column as per zero indexing
# Out:
#           Low       Close
# 0  186.910004  187.630005
# 1  186.779999  187.160004
# 2  185.759995  188.360001
# 3  186.210007  188.149994

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900
# 3  20401000
# 4  17461000

# %%
df.iloc[1,2:3]   # What it returned?
# Out:
# Low    186.779999
# Name: 2018-05-22, dtype: float64

# %% [markdown]
# ## Filtering

# %%
df['Open']<187   # It returns a boolean series
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# Name: Open, dtype: bool

# %%
df[df['Open']<187]  # retunrs a data frame with he rows tht a has OPen<187
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 2   2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 20  2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#       Volume
# 2   19467900
# 20  32502500

# %%
# What are the days Apple stocks shown some improvement?

# %%
df[(df['High']-df['Low'])<2]
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 5   2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 6   2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 10  2018-06-05  193.070007  193.940002  192.360001  193.309998  193.309998
# 12  2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 14  2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 15  2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
#
#       Volume
# 5   22369000
# 6   18690500
# 10  21566000
# 12  21347200
# 14  18308500
# 15  16911100
# 17  21610100
# 18  61719200

# %%
df[df['Close']>df['Open']][['Open','Close']]
# Out:
#           Open       Close
# 2   186.350006  188.360001
# 4   188.229996  188.580002
# 5   187.600006  187.899994
# 8   187.990005  190.240005
# 9   191.639999  191.830002
# 10  193.070007  193.309998
# 11  193.630005  193.979996
# 13  191.169998  191.699997
# 15  191.389999  192.279999
# 19  187.880005  188.740005
# 20  185.139999  185.690002

# %%
# What are the days Apple stocks didnt fluctuate much?

# %% [markdown]
# ### Combining filters

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#               Volume
# Date
# 2018-05-21  18400800
# 2018-05-22  15240700
# 2018-05-23  19467900
# 2018-05-24  20401000
# 2018-05-25  17461000

# %%
# What are the days Apple stocks opened nearly at high and closed nearly at low

# %%
df[(abs(df['Open']-df['High'])<0.5 ) & (abs(df['Close']-df['Low'])<0.5)]
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 16  2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
#
#       Volume
# 16  21638400

# %%
(abs(df['Open']-df['High'])<0.5 ) & (abs(df['Close']-df['Low'])<0.5)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
# either it opend at high are closed at low

df[(abs(df['Open']-df['High'])<0.2 ) | (abs(df['Close']-df['Low'])<0.2)]
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 3   2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 12  2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
#
#       Volume
# 3   20401000
# 12  21347200
# 17  21610100
# 18  61719200

# %% [markdown]
# ### checking non null values

# %%
df.all()  # checks if all the elements in each column are non-null
# Out:
# Date         True
# Open         True
# High         True
# Low          True
# Close        True
# Adj Close    True
# Volume       True
# dtype: bool

# %%
df.all(axis=1)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# dtype: bool

# %%
# copy 
df2=df
print(id(df),sep='\n')
print(id(df2),sep='\n')
# Out:
# 140358859582936
# 140358859582936

# %%
# Deep copy 
df2=df.copy()
print(id(df),sep='\n')
print(id(df2),sep='\n')
# Out:
# 140358859582936
# 140358859649768

# %%
df2['zeros']=0  # created a column of zeros with zero values
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#      Volume  zeros
# 0  18400800      0
# 1  15240700      0
# 2  19467900      0
# 3  20401000      0
# 4  17461000      0

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900
# 3  20401000
# 4  17461000

# %%
df2.all()
# Out:
# Date          True
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# zeros        False
# dtype: bool

# %%
df2.all(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
df2.any()
# Out:
# Date          True
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# zeros        False
# dtype: bool

# %%
df2.any(axis=1)
# Out:
# Date
# 2018-05-21    True
# 2018-05-22    True
# 2018-05-23    True
# 2018-05-24    True
# 2018-05-25    True
# 2018-05-29    True
# 2018-05-30    True
# 2018-05-31    True
# 2018-06-01    True
# 2018-06-04    True
# 2018-06-05    True
# 2018-06-06    True
# 2018-06-07    True
# 2018-06-08    True
# 2018-06-11    True
# 2018-06-12    True
# 2018-06-13    True
# 2018-06-14    True
# 2018-06-15    True
# 2018-06-18    True
# 2018-06-19    True
# dtype: bool

# %%
df2.loc[:,df2.any()]
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1   2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2   2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3   2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4   2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
# 5   2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 6   2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 7   2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
# 8   2018-06-01  187.990005  190.259995  187.750000  190.240005  190.240005
# 9   2018-06-04  191.639999  193.419998  191.350006  191.830002  191.830002
# 10  2018-06-05  193.070007  193.940002  192.360001  193.309998  193.309998
# 11  2018-06-06  193.630005  194.080002  191.919998  193.979996  193.979996
# 12  2018-06-07  194.139999  194.199997  192.339996  193.460007  193.460007
# 13  2018-06-08  191.169998  192.000000  189.770004  191.699997  191.699997
# 14  2018-06-11  191.350006  191.970001  190.210007  191.229996  191.229996
# 15  2018-06-12  191.389999  192.610001  191.149994  192.279999  192.279999
# 16  2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
# 19  2018-06-18  187.880005  189.220001  187.199997  188.740005  188.740005
# 20  2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#       Volume
# 0   18400800
# 1   15240700
# 2   19467900
# 3   20401000
# 4   17461000
# 5   22369000
# 6   18690500
# 7   27482800
# 8   23250400
# 9   26132000
# 10  21566000
# 11  20933600
# 12  21347200
# 13  26656800
# 14  18308500
# 15  16911100
# 16  21638400
# 17  21610100
# 18  61719200
# 19  18484900
# 20  32502500

# %%
import numpy as np

# %%
df2.iloc[4,3]=np.nan

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994         NaN  188.580002  188.580002
#
#      Volume  zeros
# 0  18400800      0
# 1  15240700      0
# 2  19467900      0
# 3  20401000      0
# 4  17461000      0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       21 non-null     object
#  1   Open       21 non-null     float64
#  2   High       21 non-null     float64
#  3   Low        20 non-null     float64
#  4   Close      21 non-null     float64
#  5   Adj Close  21 non-null     float64
#  6   Volume     21 non-null     int64
#  7   zeros      21 non-null     int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 1.4+ KB

# %%
df2.head(8)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 4  2018-05-25  188.229996  189.649994         NaN  188.580002  188.580002
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 6  2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 7  2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
#
#      Volume  zeros
# 0  18400800      0
# 1  15240700      0
# 2  19467900      0
# 3  20401000      0
# 4  17461000      0
# 5  22369000      0
# 6  18690500      0
# 7  27482800      0

# %%
df2.dropna(inplace=True)

# %%
df2.head(8)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 6  2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 7  2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
# 8  2018-06-01  187.990005  190.259995  187.750000  190.240005  190.240005
#
#      Volume  zeros
# 0  18400800      0
# 1  15240700      0
# 2  19467900      0
# 3  20401000      0
# 5  22369000      0
# 6  18690500      0
# 7  27482800      0
# 8  23250400      0

# %%
df2.drop('zeros',axis='columns',inplace=True)  # dropping a particular column thats not required

# %%
df2.head()  # what the above did is just returned an object after dropping but change in actual object didn't take place
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#      Volume
# 0  18400800
# 1  15240700
# 2  19467900
# 3  20401000
# 5  22369000

# %%
# Try to delete 'Adj Close' Column

# %%
df2.drop('Adj Close', axis=1,inplace=True)

# %%
df2.head(8)
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  18400800
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  15240700
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  19467900
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  20401000
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  22369000
# 2018-05-30  187.720001  188.000000  186.779999  187.500000  18690500
# 2018-05-31  187.220001  188.229996  186.139999  186.869995  27482800
# 2018-06-01  187.990005  190.259995  187.750000  190.240005  23250400

# %% [markdown]
# #### Create another column 'Change'

# %%
df2['Change']=(df2['Open']-df2['Close'])/2

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#      Volume    Change
# 0  18400800  0.369995
# 1  15240700  1.220001
# 2  19467900 -2.009995
# 3  20401000  0.620010
# 5  22369000 -0.299988

# %%
# The volume number are huge compared to others. Scale them

# %%
df2['Volume']/=100000   # this could be possible because they are internally numpy arrays

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#      Volume    Change
# 0  0.001840  0.184997
# 1  0.001524  0.610000
# 2  0.001947 -1.004998
# 3  0.002040  0.310005
# 5  0.002237 -0.149994

# %%
# Even any other numpy unversal function can be applied 

df2['Change'].abs()
# Out:
# 0     0.184997
# 1     0.610000
# 2     1.004998
# 3     0.310005
# 5     0.149994
# 6     0.110000
# 7     0.175003
# 8     1.125000
# 9     0.095002
# 10    0.119996
# 11    0.174995
# 12    0.339996
# 13    0.265000
# 14    0.060005
# 15    0.445000
# 16    0.860000
# 17    0.375000
# 18    0.595002
# 19    0.430000
# 20    0.275002
# Name: Change, dtype: float64

# %%
# abs is actually a numpy function so it can also be implemented as follows
np.abs(df2['Change'])
# Out:
# 0     0.184997
# 1     0.610000
# 2     1.004998
# 3     0.310005
# 5     0.149994
# 6     0.110000
# 7     0.175003
# 8     1.125000
# 9     0.095002
# 10    0.119996
# 11    0.174995
# 12    0.339996
# 13    0.265000
# 14    0.060005
# 15    0.445000
# 16    0.860000
# 17    0.375000
# 18    0.595002
# 19    0.430000
# 20    0.275002
# Name: Change, dtype: float64

# %% [markdown]
# ### Apply()

# %%
def qnt(x):
    return (x*2)/3

# %%
qnt(100)   # it accepts just a scalar i.e a single value as an argument
# Out:
# 66.66666666666667

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 1  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 2  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 3  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 5  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
#
#      Volume    Change
# 0  0.001840  0.184997
# 1  0.001524  0.610000
# 2  0.001947 -1.004998
# 3  0.002040  0.310005
# 5  0.002237 -0.149994

# %% [markdown]
# ### How to use it for all the elements of data frame?

# %%
df2=df2.apply(qnt)

# %%
df2["info"]="all good"

# %%
df2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Change',
#        'info'],
#       dtype='object')

# %%
df2["Low"]
# Out:
# 0     186.910004
# 1     186.779999
# 2     185.759995
# 3     186.210007
# 5     186.869995
# 6     186.779999
# 7     186.139999
# 8     187.750000
# 9     191.350006
# 10    192.360001
# 11    191.919998
# 12    192.339996
# 13    189.770004
# 14    190.210007
# 15    191.149994
# 16    190.440002
# 17    190.220001
# 18    188.259995
# 19    187.199997
# 20    183.449997
# Name: Low, dtype: float64

# %%
df2['Open'].apply(qnt)
# Out:
# 0     125.333333
# 1     125.586670
# 2     124.233337
# 3     125.846669
# 5     125.066671
# 6     125.146667
# 7     124.813334
# 8     125.326670
# 9     127.759999
# 10    128.713338
# 11    129.086670
# 12    129.426666
# 13    127.446665
# 14    127.566671
# 15    127.593333
# 16    128.279999
# 17    127.700002
# 18    126.686666
# 19    125.253337
# 20    123.426666
# Name: Open, dtype: float64

# %%
def lm(x):
    return x/2

# %%
df2['Open'].apply(lambda x:2*x/32)
# Out:
# 0     11.750000
# 1     11.773750
# 2     11.646875
# 3     11.798125
# 5     11.725000
# 6     11.732500
# 7     11.701250
# 8     11.749375
# 9     11.977500
# 10    12.066875
# 11    12.101875
# 12    12.133750
# 13    11.948125
# 14    11.959375
# 15    11.961875
# 16    12.026250
# 17    11.971875
# 18    11.876875
# 19    11.742500
# 20    11.571250
# Name: Open, dtype: float64

# %% [markdown]
# ## Saving the changes into a file

# %%
df2.to_csv('./Data/changes.csv')

# %%
df2.to_excel('./Data/chg.xls')

# %%
# melt

# %%
df2.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 16  2018-06-13  192.419998  192.880005  190.440002  190.699997  190.699997
# 17  2018-06-14  191.550003  191.570007  190.220001  190.800003  190.800003
# 18  2018-06-15  190.029999  190.160004  188.259995  188.839996  188.839996
# 19  2018-06-18  187.880005  189.220001  187.199997  188.740005  188.740005
# 20  2018-06-19  185.139999  186.330002  183.449997  185.690002  185.690002
#
#       Volume    Change      info
# 16  0.002164  0.860000  all good
# 17  0.002161  0.375000  all good
# 18  0.006172  0.595002  all good
# 19  0.001848 -0.430000  all good
# 20  0.003250 -0.275002  all good

# %%
dfn=df2.melt(id_vars=['Date','High'],value_name="val")

# %%
dfn.groupby(by='Date')

# %%
dfn.head()
# Out:
#          Date        High variable     val
# 0  2018-05-21  189.270004     Open     188
# 1  2018-05-22  188.880005     Open  188.38
# 2  2018-05-23  188.500000     Open  186.35
# 3  2018-05-24  188.839996     Open  188.77
# 4  2018-05-29  188.750000     Open   187.6

# %%
dfn.pivot_table(columns='variable')
# Out:
# variable   Adj Close      Change       Close         Low        Open  \
# High      190.655501  190.655501  190.655501  190.655501  190.655501
#
# variable      Volume        info
# High      190.655501  190.655501
